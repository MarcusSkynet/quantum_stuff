# %%
from qiskit import *

# %%
circuit = QuantumCircuit(2,2)

# %%
circuit.draw()

# %%
circuit.h(0)
circuit.draw()

# %%
circuit.cx(0,1) # 0 -> control qupit, 1 -> target qubit
circuit.measure([0,1],[0,1])
circuit.draw()

# %%
simulator = Aer.get_backend('qasm_simulator')

# %%
result = execute(circuit,backend=simulator).result()

# %%
from qiskit.visualization import plot_histogram

# %%
plot_histogram(result.get_counts(circuit))

# %%
IBMQ.load_account()
# Out:
# ibmqfactory.load_account:WARNING:2023-10-10 14:30:53,367: Credentials are already in use. The existing account in the session will be replaced.
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
provider = IBMQ.get_provider('ibm-q')

# %%
quantum_computer = provider.get_backend('ibm_nairobi')

# %%
import qiskit.tools.jupyter
# %qiskit_job_watcher

job = execute(circuit,backend=quantum_computer)
# Out:
# Accordion(children=(VBox(layout=Layout(max_width='710px', min_width='710px')),), layout=Layout(max_height='500…

# %%
quantum_result = job.result()
plot_histogram(quantum_result.get_counts(circuit))

# %%
from qiskit.tools.monitor import job_monitor
job_monitor(job)
# Out:
# Job Status: job has successfully run
